# %% [markdown]
# # Exploration

# %%
from astra_core import CodeUnit, analyze_code_similarity

threshold = 0.8

units = [
    CodeUnit(
        id="student_a.py",
        content="""
def compute_sum(numbers):
    total = 0
    for n in numbers:
        total += n
    return total

data = [5, 10, 15, 20]
print(compute_sum(data))
""",
    ),
    CodeUnit(
        id="student_b.py",
        content="""
def sum_values(vals):
    acc = 0
    for v in vals:
        acc += v
    return acc

nums = [1, 2, 3, 4]
output = sum_values(nums)
print(output)
""",
    ),
]

result = analyze_code_similarity(
    units=units,
    threshold=threshold,
)

print(result)
# Out:
# AnalysisReport(threshold=0.8, total_units=2, scores=[SimilarityScore(unit_a='student_a.py', unit_b='student_b.py', score=0.7916666666666666, alignment_count=4, chunk_count_a=2, chunk_count_b=4, evidence=(ChunkAlignment(left_chunk_index=0, right_chunk_index=0, similarity=1.0, distance=0, left_kind='FunctionDef', right_kind='FunctionDef', left_tokens=('FunctionDef', 'IDENT', 'IDENT', 'arguments', 'arg', 'ARG', 'IDENT', 'Assign', 'Name', 'IDENT', 'IDENT', 'Store', 'Constant', 'CONST_NUM', 'NUM', 'For', 'Name', 'IDENT', 'IDENT', 'Store', 'Name', 'IDENT', 'IDENT', 'Load', 'AugAssign', 'Name', 'IDENT', 'IDENT', 'Store', 'Add', 'Name', 'IDENT', 'IDENT', 'Load', 'Return', 'Name', 'IDENT', 'IDENT', 'Load'), right_tokens=('FunctionDef', 'IDENT', 'IDENT', 'arguments', 'arg', 'ARG', 'IDENT', 'Assign', 'Name', 'IDENT', 'IDENT', 'Store', 'Constant', 'CONST_NUM', 'NUM', 'For', 'Name', 'IDENT', 'IDENT', 'Store', 'Name', 'IDENT', 'IDENT', 'Load', 'AugAssign', 'Name', 'IDENT', 'IDENT', 'Store', 'Add', 'Name', 'IDENT', 'IDENT', 'Load', 'Return', 'Name', 'IDENT', 'IDENT', 'Load')), ChunkAlignment(left_chunk_index=1, right_chunk_index=2, similarity=0.8, distance=3, left_kind='Expr', right_kind='Assign', left_tokens=('Expr', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Name', 'IDENT', 'IDENT', 'Load'), right_tokens=('Assign', 'Name', 'IDENT', 'IDENT', 'Store', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Name', 'IDENT', 'IDENT', 'Load')), ChunkAlignment(left_chunk_index=1, right_chunk_index=3, similarity=0.6666666666666667, distance=5, left_kind='Expr', right_kind='Expr', left_tokens=('Expr', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Name', 'IDENT', 'IDENT', 'Load'), right_tokens=('Expr', 'Call', 'Name', 'IDENT', 'IDENT', 'Load', 'Name', 'IDENT', 'IDENT', 'Load')), ChunkAlignment(left_chunk_index=0, right_chunk_index=1, similarity=0.20512820512820518, distance=31, left_kind='FunctionDef', right_kind='Assign', left_tokens=('FunctionDef', 'IDENT', 'IDENT', 'arguments', 'arg', 'ARG', 'IDENT', 'Assign', 'Name', 'IDENT', 'IDENT', 'Store', 'Constant', 'CONST_NUM', 'NUM', 'For', 'Name', 'IDENT', 'IDENT', 'Store', 'Name', 'IDENT', 'IDENT', 'Load', 'AugAssign', 'Name', 'IDENT', 'IDENT', 'Store', 'Add', 'Name', 'IDENT', 'IDENT', 'Load', 'Return', 'Name', 'IDENT', 'IDENT', 'Load'), right_tokens=('Assign', 'Name', 'IDENT', 'IDENT', 'Store', 'List', 'Constant', 'CONST_NUM', 'NUM', 'Constant', 'CONST_NUM', 'NUM', 'Constant', 'CONST_NUM', 'NUM', 'Constant', 'CONST_NUM', 'NUM', 'Load'))))], flagged_pairs=[], metadata={'algorithm': 'ast-normalized-damerau-levenshtein', 'chunking': 'top-level-ast-statements', 'tokenization': 'preorder-normalized-ast', 'unit_chunk_counts': {'student_a.py': 2, 'student_b.py': 4}})
